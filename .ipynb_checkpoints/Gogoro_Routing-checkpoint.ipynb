# %% [markdown]
# # Gogoro_routing
# ## Normal import

# %%
import pandas as pd
import numpy as np
import requests
import geopy.distance
import googlemaps

# %% [markdown]
# ## Google colab import and install

# %%
# Cell for google colab
from google.colab import drive
drive.mount('/content/drive')
pip install googlemaps

# %% [markdown]
# ## read station from file

# %%
file_url_st_info = 'data/station_info.csv'
file_url_google_colab_st_info = '/content/drive/My Drive/Gogoro_Routing/data/station_info.csv'
station_df = pd.read_csv(file_url_st_info,index_col = 0)
# station_df.head()

# %%
file_url_ll_df = 'data/ll_matrix.csv'
file_url_google_colab_ll_df = '/content/drive/My Drive/Gogoro_Routing/data/ll_matrix.csv'
ll_df = pd.read_csv(file_url_ll_df,index_col = 0)
# ll_df.head()

# %%
file_url_key = 'confidential/gmap_api_key.txt'
fiel_url_google_colab_key = '/content/drive/My Drive/Gogoro_Routing/confidential/gmap_api_key.txt'
f = open(file_url_key,encoding="utf-8")
gmaps_key = f.readline()

# %% [markdown]
# ## Calculate google map distance

# %%
def GoogleMap_Distance(station1_latitude,station1_longitude,station2_latitude,station2_longitude):    
    url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
    url += 'origins='+str(station1_latitude)+','+str(station1_longitude)
    url += '&destinations='+str(station2_latitude)+','+str(station2_longitude)
    url += '&mode=driving'
    url += '&avoid=tolls|highways|ferries'
    url += '&key='+gmaps_key
    url
    resp = requests.get(url)
    print('gmap_distance:',resp.json()['rows'][0]['elements'][0]['distance']['text'])
    return resp.json()['rows'][0]['elements'][0]['distance']['text']

# %%
def Multi_GoogleMap_Distance(origin_ll,list_dest_ll):
    # process list of latitude and longitude
    list_dest_ll_str =''
    for i in list_dest_ll:
        list_dest_ll_str += i + '|'
    list_dest_ll_str = list_dest_ll_str[:-1]
#     print(list_dest_ll_str)
    
    url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
    url += 'origins=' + origin_ll
    url += '&destinations='+ list_dest_ll_str
    url += '&mode=driving'
    url += '&avoid=tolls|highways|ferries'
    url += '&key='+gmaps_key
#     print(url)
    resp = requests.get(url)
    list_dist = [i['distance']['value']/1000 for i in resp.json()['rows'][0]['elements']]
    return list_dist

# %% [markdown]
# ## Construct adjacent graph for stations using Google maps

# %%
gmap_df = pd.DataFrame(index=ll_df.index,columns=ll_df.columns)
# gmap_df

MAX_QUERY_DEST = 25 # max query numbers for destinations of google maps distance matrix api in one call is 25
MAX_BOUNDARY = 80 # only calculate station distance within 80km boundary
station_num = len(ll_df)

for i in range(1):
    station1 = ll_df.index[i]
    origin_ll = str(station_df.loc[station1]['Latitude']) + ',' + str(station_df.loc[station1]['Longitude'])
#     print(origin_ll)
    list_dest_ll = {}
    
    for j in range(i+1,26):
        station2 = ll_df.index[j]
        if ll_df.loc[station1,station2] < MAX_BOUNDARY:
            dest_ll = str(station_df.loc[station2]['Latitude']) + ',' + str(station_df.loc[station2]['Longitude'])
            list_dest_ll[station2] = dest_ll
            if len(list_dest_ll) == MAX_QUERY_DEST:
                list_dest_dist = dict(zip(list_dest_ll.keys(),Multi_GoogleMap_Distance(origin_ll,list(list_dest_ll.values()))))
                for dest,dist in list_dest_dist.items():
                    gmap_df.loc[station1][dest] = dist
                list_dest_ll.clear()

file_url_gmap_df = 'data/gmap_matrix1.csv'
file_url_google_colab_gmap_df = ''
gmap_df.to_csv(file_url_gmap_df)
gmap_df.head()
# Out:
#                                      865a6d73-ab7d-4176-a542-09898fbf7dca  \
# 865a6d73-ab7d-4176-a542-09898fbf7dca                                  NaN
# cc480eeb-93c4-49b1-9b12-15474249b5bf                                  NaN
# 5a72a2fb-505c-476b-a796-17fcf769c99a                                  NaN
# 41c44a19-d494-4845-a659-19d5cba5b29a                                  NaN
# 5dfa7fd8-2148-4fb2-b3b3-2d98949c0227                                  NaN
#
#                                      cc480eeb-93c4-49b1-9b12-15474249b5bf  \
# 865a6d73-ab7d-4176-a542-09898fbf7dca                               14.429
# cc480eeb-93c4-49b1-9b12-15474249b5bf                                  NaN
# 5a72a2fb-505c-476b-a796-17fcf769c99a                                  NaN
# 41c44a19-d494-4845-a659-19d5cba5b29a                                  NaN
# 5dfa7fd8-2148-4fb2-b3b3-2d98949c0227                                  NaN
#
# ...

# %% [markdown]
# ## 草稿code

# %%
# call multiple destination google maps api
temp_list = ['cc480eeb-93c4-49b1-9b12-15474249b5bf', '5a72a2fb-505c-476b-a796-17fcf769c99a', '41c44a19-d494-4845-a659-19d5cba5b29a', '5dfa7fd8-2148-4fb2-b3b3-2d98949c0227', '72448e88-d147-4640-8e72-2f5f85240484', '7ae3c1f2-c250-4032-ac8c-30b76d37aea0', '6ae3b11f-dee5-4944-9c0a-310a956c3e9c', '911d709e-a0c6-4f07-ad76-364cfa8091e6', '99c0fa96-2d0a-41e2-8d45-3bac8afdfb91', '5aa573ac-9749-4b44-96d9-45c011271bff', '24d2d276-80fb-44ff-83af-49003d3527ec', '7d5915e0-c312-4c5d-98f0-49448f23c7cd', 'cc7c84a5-f7ce-412e-8ca8-52c2fa4277e6', '10e4ebb6-6428-47ae-85df-6266dabca45f', '3e742441-cd80-419f-923b-637ddb26dc30', '20839915-f8ce-48ba-9b30-6dad16baf33e', '766c02fe-2556-4d5a-ae40-6fa8a07de439', '9aebcaf8-4416-4735-9f88-79acf059b9c1', '5fd41ebc-d4fd-4a54-974e-88539d6d4753', '9378da9a-e89b-4b69-aa85-9430ca8f9d15', '36ba5441-6d4b-4880-b2c8-a228279d33f2', '7428bf0b-d4c8-4b25-aa12-b05d587db155', '578be395-f2e2-4d88-a20e-b99f0e5c9dda', '38eb9036-e4ee-4b1c-bd06-bc87b40133e7', '6538b6c2-7caa-4b37-8363-c3610c992912']

temp_str = ''
for i in temp_list:
    lat = str(station_df.loc[i]['Latitude'])
    longt = str(station_df.loc[i]['Longitude'])
    tmp_str = lat + ',' + longt
    temp_str += tmp_str + '|'
temp_str = temp_str[:-1]
temp_str
# lati = station_df.loc[station_df.index[0]]['Latitude']
# longt = station_df.loc[station_df.index[0]]['Longitude']
# json = Multi_GoogleMap_Distance(lati,longt,temp_str)
# json
# list_dist = [i['distance']['value']/1000 for i in json['rows'][0]['elements']]
# list_dist
# Out:
# '23.703846,120.55058899999999|23.715782,120.53048899999999|23.678779000000002,120.393428|23.707607,120.43124499999999|23.794078,120.27305700000001|23.794191,120.46291000000001|23.581828,120.185033|23.715078,120.535096|23.569473000000002,120.299535|23.723612,120.58176100000001|23.773694,120.41731499999999|23.698961999999998,120.202715|23.702237,120.53064599999999|23.775305,120.478746|23.707167000000002,120.43623799999999|23.65044,120.560197|23.712018,120.535376|23.726775,120.52384099999999|23.734516,120.41553300000001|23.707276,120.537416|23.677689,120.463232|23.717177,120.42501899999999|23.752329,120.610665|23.700789999999998,120.52768999999999|23.7563,120.50450500000001'

# %%
# Comparing distance calculate method 

# find two sample stations -> LocName=['HiLife 八里聖心店站', '新北市民生立體停車場站']
sample_station = ['45FC384A-CA7D-43B3-98A7-8A5B635331F5','C9B55157-153A-4C07-91D5-A3C9131F110D']
sample_station = [i.lower() for i in sample_station]


# Method 1: Lat Long calculate
coord_0 = (station_df.loc[sample_station[0]]['Latitude'],station_df.loc[sample_station[0]]['Longitude'])
coord_1 = (station_df.loc[sample_station[1]]['Latitude'],station_df.loc[sample_station[1]]['Longitude'])
ll_distance = geopy.distance.distance(coord_0,coord_1).km
print('ll_distance: ', ll_distance, 'km')

# Method 2: Google distance matrix
file_url_key = 'confidential/gmap_api_key.txt'
fiel_url_google_colab_key = ''
f = open(file_url_key,encoding="utf-8")
gmaps_key = f.readline() 
url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
url += 'origins='+str(coord_0[0])+','+str(coord_0[1])
url += '&destinations='+str(coord_1[0])+','+str(coord_1[1])
url += '&mode=driving'
url += '&avoid=tolls|highways|ferries'
url += '&key='+gmaps_key
url
resp = requests.get(url)
print('gmap_distance:',resp.json()['rows'][0]['elements'][0]['distance']['text'])

# gmaps api沒辦法支持多avoid
# gmaps = googlemaps.Client(key=gmaps_key)
# gmaps.distance_matrix(origins=str(coord_0[0])+','+str(coord_0[1]),destinations=str(coord_1[0])+','+str(coord_1[1]), mode='driving', avoid='tolls|highways')
# Out:
# ll_distance:  1.4162488132720112 km
# gmap_distance: 4.9 km
